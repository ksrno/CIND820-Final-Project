# %% [markdown]
# Dataset Link: https://www.kaggle.com/datasets/oktayrdeki/traffic-accidents

# %%
# !pip install ydata-profiling

# %%
import pandas as pd
from ydata_profiling import ProfileReport

df = pd.read_csv('/content/traffic_accidents.csv')

# %%
injury_rank = {
    'NO INDICATION OF INJURY': 0,
    'REPORTED, NOT EVIDENT': 1,
    'NONINCAPACITATING INJURY': 2,
    'INCAPACITATING INJURY': 3,
    'FATAL': 4
}

# %%
df['injury_severity'] = df['most_severe_injury'].map(injury_rank)

# %%
profile = ProfileReport(df, title="Profiling Report")

# %%
profile

# %%
    profile.to_file("your_report.html") # Replace "your_report.html" with your desired filename
